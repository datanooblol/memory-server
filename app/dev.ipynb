# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from package.data_models.user import User

user = User(email="haha@gmail.com", password="abcdef")
user
# Out:
# User(user_id='008d4a67-1738-4ee9-b727-7816ae97f903', email='haha@gmail.com', password='abcdef', created_at=datetime.datetime(2025, 12, 5, 17, 35, 40, 977301, tzinfo=<DstTzInfo 'Asia/Bangkok' +07+7:00:00 STD>), updated_at=datetime.datetime(2025, 12, 5, 17, 35, 40, 977314, tzinfo=<DstTzInfo 'Asia/Bangkok' +07+7:00:00 STD>))
